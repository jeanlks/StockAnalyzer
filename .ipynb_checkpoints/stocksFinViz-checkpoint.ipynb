# %%
#!pip install urllib3
#!pip install bs4

# For data manipulation
import pandas as pd
from urllib.request import urlopen, Request
import numpy as np

# To extract fundamental data
from bs4 import BeautifulSoup

# %%
def transform_to_millions(value):
    if pd.isna(value) or value == '-':
        return np.nan
    suffix = value[-1]  # Get the last character (M, B, etc.)
    num = float(value[:-1])  # Get the numeric part
    if suffix == 'M':
        return num * 1e6  # Convert to millions
    elif suffix == 'B':
        return num * 1e9  # Convert to billions
    else:
        return num  # Return as is if no suffix

# %% [markdown]
# # Functions to Parse Data from FinViz

# %% [markdown]
# # Initialize Pandas DataFrame to Store the Data

# %%
output_directory = "output/"
input_directory = "input/"
csv_name='nasdaq-2023-05-31'
df = pd.read_csv(input_directory+csv_name+".csv",index_col=0)
df.head(10)
# Out:
#         P/B    P/E Forward P/E   PEG Debt/Eq EPS (ttm) Dividend %      ROE  \
# AVAV   3.69      -       44.45     -    0.27     -0.34          -   -1.40%
# SGRP   1.17      -        4.68     -    0.87     -0.03          -  -10.80%
# PWUP    NaN    NaN         NaN   NaN     NaN       NaN        NaN      NaN
# SCHL   1.23  25.09       15.88  2.76    0.00      1.68      1.90%    5.20%
# QH     0.02      -           -     -    0.13     -4.96          -   -2.70%
# SABR      -      -       14.52     -       -     -1.84          -   74.90%
# LMB    2.15  19.56       14.22  1.63    0.30      1.04          -   12.00%
# QSG       -      -           -     -       -     -1.17          -        -
# ENTF    NaN    NaN         NaN   NaN     NaN       NaN        NaN      NaN
# HCTI  13.96      -           -     -    0.31     -2.27          -        -
#
#           ROI   EPS Q/Q Insider Own EPS next Y    Income Perf Year Perf YTD  \
# AVAV    0.90%         -       0.90%       2.06    -8.50M    -3.66%    7.96%
# SGRP    6.20%    45.40%      18.50%       0.25    -0.70M    -5.42%  -12.69%
# PWUP      NaN       NaN         NaN        NaN       NaN       NaN      NaN
# SCHL    7.20%   -28.80%       1.10%       2.65    62.10M    11.08%    6.35%
# QH      2.60%   125.60%           -          -    -1.90M   -50.23%   46.02%
# SABR   -7.10%  -408.40%       1.00%       0.22  -602.00M   -58.57%  -49.51%
# LMB     7.30%   286.30%       0.20%       1.43    11.30M   286.83%  100.29%
# QSG    32.10%         -       1.04%          -         -         -  -27.96%
# ENTF      NaN       NaN         NaN        NaN       NaN       NaN      NaN
# HCTI  -70.80%   -38.30%      64.68%          -   -10.90M   -67.74%   45.74%
#
#      Profit Margin  Payout    Sales
# AVAV        -1.70%       -  487.10M
# SGRP        -1.00%       -  261.30M
# PWUP           NaN     NaN      NaN
# SCHL         3.70%  39.10%    1.69B
# QH          -0.30%       -  539.70M
# SABR       -22.40%       -    2.69B
# LMB          2.20%   0.00%  503.00M
# QSG              -       -  390.70M
# ENTF           NaN     NaN      NaN
# HCTI             -       -   44.70M

# %% [markdown]
# # Data Clearning: Further Parse the Data into Numeric Types
# Remove % Sign and Convert Values to Numeric Type

# %%
df['Dividend %'] = df['Dividend %'].str.replace('%', '')
df['ROE'] = df['ROE'].str.replace('%', '')
df['ROI'] = df['ROI'].str.replace('%', '')
df['EPS Q/Q'] = df['EPS Q/Q'].str.replace('%', '')
df['EPS next Y'] = df['EPS next Y'].str.replace('%', '')
df['Insider Own'] = df['Insider Own'].str.replace('%', '')
df['Perf YTD'] = df['Perf YTD'].str.replace('%', '')
df['Perf Year'] = df['Perf Year'].str.replace('%', '')
df['Income'] = df['Income'].apply(lambda x: transform_to_millions(x))
df['Profit Margin'] = df['Profit Margin'].str.replace('%', '')
df = df.apply(pd.to_numeric, errors='coerce')
df
# Out:
#         P/B    P/E  Forward P/E   PEG  Debt/Eq  EPS (ttm)  Dividend %   ROE  \
# AVAV   3.69    NaN        44.45   NaN     0.27      -0.34         NaN  -1.4
# SGRP   1.17    NaN         4.68   NaN     0.87      -0.03         NaN -10.8
# PWUP    NaN    NaN          NaN   NaN      NaN        NaN         NaN   NaN
# SCHL   1.23  25.09        15.88  2.76     0.00       1.68         1.9   5.2
# QH     0.02    NaN          NaN   NaN     0.13      -4.96         NaN  -2.7
# ...     ...    ...          ...   ...      ...        ...         ...   ...
# GAN     NaN    NaN          NaN   NaN      NaN        NaN         NaN   NaN
# SRZN    NaN    NaN          NaN   NaN      NaN        NaN         NaN   NaN
# OCAXU   NaN    NaN          NaN   NaN      NaN        NaN         NaN   NaN
# ACTG    NaN    NaN          NaN   NaN      NaN        NaN         NaN   NaN
# SJ      NaN    NaN          NaN   NaN      NaN        NaN         NaN   NaN
#
#        ROI  EPS Q/Q  Insider Own  EPS next Y      Income  Perf Year  Perf YTD  \
# AVAV   0.9      NaN          0.9        2.06  -8500000.0      -3.66      7.96
# SGRP   6.2     45.4         18.5        0.25   -700000.0      -5.42    -12.69
# PWUP   NaN      NaN          NaN         NaN         NaN        NaN       NaN
# SCHL   7.2    -28.8          1.1        2.65  62100000.0      11.08      6.35
# QH     2.6    125.6          NaN         NaN  -1900000.0     -50.23     46.02
# ...    ...      ...          ...         ...         ...        ...       ...
# GAN    NaN      NaN          NaN         NaN         NaN        NaN       NaN
# SRZN   NaN      NaN          NaN         NaN         NaN        NaN       NaN
# OCAXU  NaN      NaN          NaN         NaN         NaN        NaN       NaN
# ACTG   NaN      NaN          NaN         NaN         NaN        NaN       NaN
# SJ     NaN      NaN          NaN         NaN         NaN        NaN       NaN
#
#        Profit Margin  Payout  Sales
# AVAV            -1.7     NaN    NaN
# SGRP            -1.0     NaN    NaN
# PWUP             NaN     NaN    NaN
# SCHL             3.7     NaN    NaN
# QH              -0.3     NaN    NaN
# ...              ...     ...    ...
# GAN              NaN     NaN    NaN
# SRZN             NaN     NaN    NaN
# OCAXU            NaN     NaN    NaN
# ACTG             NaN     NaN    NaN
# SJ               NaN     NaN    NaN
#
# [4553 rows x 18 columns]

# %% [markdown]
# # Filter Good Companies
#
# ### 1. Companies which are quoted at low valuations
# P/E < 15 and P/B < 1

# %%
df_filtered = df[(df['P/E'].astype(float)<25) & (df['P/B'].astype(float) < 1)]
df_filtered = df_filtered[(df_filtered['Profit Margin'].astype(float) > 10)]
df_filtered
# Out:
#        P/B   P/E  Forward P/E   PEG  Debt/Eq  EPS (ttm)  Dividend %   ROE  \
# IROQ  0.61  8.89          NaN   NaN     0.00       1.59        2.82   7.2
# CGBD  0.81  9.84         6.94  4.92     1.26       1.40       10.71   9.1
# BRKL  0.63  7.17         6.61  1.20     0.15       1.19        6.33   9.1
# PEBO  0.90  7.13         7.30  0.89     0.08       3.71        5.91  13.2
# SRTS  0.97  7.35        10.41   NaN     0.00       0.38         NaN  13.5
# ...    ...   ...          ...   ...      ...        ...         ...   ...
# PFIS  0.88  8.07         8.99   NaN     0.10       5.00        4.06  11.5
# NAVI  0.67  4.26         5.07  0.57    21.35       3.60        4.17  16.9
# ASRV  0.46  7.41          NaN   NaN     0.00       0.38        4.24   6.2
# AMAL  0.87  5.06         4.98   NaN     0.15       2.85        2.77  14.4
# FNCB  0.86  5.82          NaN   NaN     0.08       0.95        6.50  15.5
#
#        ROI  EPS Q/Q  Insider Own  EPS next Y       Income  Perf Year  \
# IROQ  27.5    -42.0          4.8         NaN    5100000.0     -46.37
# CGBD   5.4     -6.0          0.2        1.99   79400000.0      -2.75
# BRKL  22.0    -72.5          2.7        1.29   92600000.0     -42.98
# PEBO  26.9     12.8          1.8        3.62  103800000.0      -8.51
# SRTS  23.0   -112.1          8.1        0.27    6300000.0     -69.53
# ...    ...      ...          ...         ...          ...        ...
# PFIS  25.5    -21.1          1.2        4.49   36000000.0     -25.72
# NAVI   0.9    -48.8          2.8        3.02  501000000.0      -7.18
# ASRV  17.3    -37.4          4.3         NaN    6500000.0     -29.94
# AMAL  24.2     56.7         26.2        2.90   88700000.0     -29.17
# FNCB  37.1    -37.9         16.5         NaN   18800000.0     -28.99
#
#       Perf YTD  Profit Margin  Payout  Sales
# IROQ    -18.26           17.2     NaN    NaN
# CGBD     -4.13           36.4     NaN    NaN
# BRKL    -41.45           23.0     NaN    NaN
# PEBO     -8.99           35.0     NaN    NaN
# SRTS    -63.21           16.7     NaN    NaN
# ...        ...            ...     ...    ...
# PFIS    -24.00           29.8     NaN    NaN
# NAVI     -8.81           37.7     NaN    NaN
# ASRV    -28.70           12.4     NaN    NaN
# AMAL    -38.67           24.8     NaN    NaN
# FNCB    -32.28           28.3     NaN    NaN
#
# [113 rows x 18 columns]

# %% [markdown]
# ### 2. Further filter companies which have demonstrated earning power
# EPS Q/Q > 10%

# %%
df_filtered = df_filtered[df_filtered['EPS next Y'].astype(float) > 5]
df_filtered
# Out:
#        P/B   P/E  Forward P/E   PEG  Debt/Eq  EPS (ttm)  Dividend %   ROE  \
# NRIM  0.96  7.67         7.30   NaN     0.05       4.92        6.36  13.0
# CHK   0.99  1.59        11.44   NaN     0.20      47.60       10.53  89.0
# ZION  0.90  4.94         5.63   NaN     0.14       5.85        5.67  18.8
# PNFP  0.70  6.93         7.27  0.22     0.08       7.27        1.75  10.6
# INDB  0.72  7.65         8.80  3.06     0.04       5.94        4.84   9.5
#
#        ROI  EPS Q/Q  Insider Own  EPS next Y        Income  Perf Year  \
# NRIM  37.4    -30.4         1.20        5.17  2.830000e+07     -10.94
# CHK   41.4    251.8         0.10        6.60  7.020000e+09     -23.19
# ZION  42.2      4.6         1.00        5.13  8.730000e+08     -52.12
# PNFP  16.1      6.4         2.21        6.93  5.537000e+08     -40.98
# INDB  17.4     21.4         0.40        5.16  2.720000e+08     -47.67
#
#       Perf YTD  Profit Margin  Payout  Sales
# NRIM    -31.75           25.8     NaN    NaN
# CHK     -19.70           50.8     NaN    NaN
# ZION    -44.45           28.5     NaN    NaN
# PNFP    -34.55           34.2     NaN    NaN
# INDB    -48.21           39.5     NaN    NaN

# %% [markdown]
# # Filtering for good debt ratio

# %%
df_filtered = df_filtered[df_filtered['Debt/Eq'].astype(float) < 0.8]
df_filtered
# Out:
#        P/B   P/E  Forward P/E   PEG  Debt/Eq  EPS (ttm)  Dividend %   ROE  \
# NRIM  0.96  7.67         7.30   NaN     0.05       4.92        6.36  13.0
# CHK   0.99  1.59        11.44   NaN     0.20      47.60       10.53  89.0
# ZION  0.90  4.94         5.63   NaN     0.14       5.85        5.67  18.8
# PNFP  0.70  6.93         7.27  0.22     0.08       7.27        1.75  10.6
# INDB  0.72  7.65         8.80  3.06     0.04       5.94        4.84   9.5
#
#        ROI  EPS Q/Q  Insider Own  EPS next Y  Income  Perf Year  Perf YTD  \
# NRIM  37.4    -30.4         1.20        5.17   28.30     -10.94    -31.75
# CHK   41.4    251.8         0.10        6.60    7.02     -23.19    -19.70
# ZION  42.2      4.6         1.00        5.13  873.00     -52.12    -44.45
# PNFP  16.1      6.4         2.21        6.93  553.70     -40.98    -34.55
# INDB  17.4     21.4         0.40        5.16  272.00     -47.67    -48.21
#
#       Profit Margin  Payout  Sales
# NRIM           25.8     NaN    NaN
# CHK            50.8     NaN    NaN
# ZION           28.5     NaN    NaN
# PNFP           34.2     NaN    NaN
# INDB           39.5     NaN    NaN

# %%
df_filtered.to_csv(output_directory+csv_name+"output.csv", index=True)
